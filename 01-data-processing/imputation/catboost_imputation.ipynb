# %%
import pandas as pd
# from ydata_profiling import ProfileReport

# %%
df = pd.read_parquet('/Users/vancescadinh/Documents/house-price-prediction/01-data-processing/data/data_numerical.parquet', engine='pyarrow')
df.drop(columns='address', inplace=True)
df.sample(2)
# Out:
#                                          price  construction year  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de  285000.0             1979.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077  317275.0                NaN
#
#                                       building condition  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                 2.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                 NaN
#
#                                       asbestos certificate  living area  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                   1.0         50.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                   NaN          NaN
#
#                                       bedrooms  bathrooms  toilets  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de       1.0        1.0      1.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077       NaN        NaN      NaN
#
#                                       primary energy consumption  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                       143.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                         NaN
#
#                                       energy class  ...  \
# uuid                                                ...
# 1acdc8b9-cc81-4290-a553-0ac96fad70de           4.0  ...
# 808ac0fb-8a54-4fac-8cb7-aaac05152077           NaN  ...
#
#                                       planning permission obtained  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                             1
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                             0
#
#                                       subdivision permit  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                 0.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                 NaN
#
#                                       possible priority purchase right  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                               0.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                               NaN
#
#                                       non-flood zone  g-score  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de               1      1.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077               0      NaN
#
#                                       shared building  surface of the plot  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de              0.0                  NaN
# 808ac0fb-8a54-4fac-8cb7-aaac05152077              NaN                  NaN
#
#                                       sewer network connection  \
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                       NaN
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                       NaN
#
#                                       designated land use  double glazing
# uuid
# 1acdc8b9-cc81-4290-a553-0ac96fad70de                  NaN             1.0
# 808ac0fb-8a54-4fac-8cb7-aaac05152077                  NaN             NaN
#
# [2 rows x 21 columns]

# %%
categorical_variables = ['construction year', 'asbestos certificate', 
                         'shared building', 'bedrooms', 'building condition', 
                         'possible priority purchase right', 
                         'inspection report of the electrical installation', 
                         'subdivision permit', 'sewer network connection', 
                         'planning permission obtained', 'non-flood zone', 
                         'g-score', 'double glazing', 'energy class', 
                         'bathrooms', 'toilets', 'designated land use']

for col in categorical_variables:
    df[col] = df[col].astype('category')

# df['construction year'] = df['construction year'].apply(lambda x: int(x) if pd.notnull(x) else pd.NA)

# %%
# profile = ProfileReport(df, title="EDA Report Numerical Values", explorative=True)
# profile.to_file("EDA_numerical_values.html")

# %% [markdown]
# ## Imputation with CatBoost

# %%
from catboost import CatBoostRegressor, CatBoostClassifier

# %%
df_new = df.copy()

# %%
df_new.sample(2)
# Out:
#                                          price construction year  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09  333050.0            2024.0
# f9235203-352d-46d9-98d5-c176155f9d97  325000.0               NaN
#
#                                      building condition asbestos certificate  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                NaN                  NaN
# f9235203-352d-46d9-98d5-c176155f9d97                4.0                  1.0
#
#                                       living area bedrooms bathrooms toilets  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09        108.0      2.0       1.0     2.0
# f9235203-352d-46d9-98d5-c176155f9d97        306.0      3.0       1.0     4.0
#
#                                       primary energy consumption energy class  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                         NaN          NaN
# f9235203-352d-46d9-98d5-c176155f9d97                         NaN          8.0
#
#                                       ... planning permission obtained  \
# uuid                                  ...
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09  ...                            1
# f9235203-352d-46d9-98d5-c176155f9d97  ...                            1
#
#                                      subdivision permit  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                0.0
# f9235203-352d-46d9-98d5-c176155f9d97                0.0
#
#                                      possible priority purchase right  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                              0.0
# f9235203-352d-46d9-98d5-c176155f9d97                              0.0
#
#                                      non-flood zone g-score shared building  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09              0     NaN             0.0
# f9235203-352d-46d9-98d5-c176155f9d97              1     1.0             0.0
#
#                                      surface of the plot  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                 NaN
# f9235203-352d-46d9-98d5-c176155f9d97               770.0
#
#                                       sewer network connection  \
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                       NaN
# f9235203-352d-46d9-98d5-c176155f9d97                       1.0
#
#                                      designated land use double glazing
# uuid
# d0eb7349-5946-4dc9-b0e0-5bfb1f89ef09                 NaN            1.0
# f9235203-352d-46d9-98d5-c176155f9d97                 1.0            1.0
#
# [2 rows x 21 columns]

# %%
# cat_df = df_new[categorical_variables]

# %%
# TEST - one categorical variable - construction year
for col in categorical_variables:
    if isinstance(df_new[col].dtype, pd.CategoricalDtype):
        df_new[col] = df_new[col].cat.add_categories('Missing').fillna('Missing')
    else:
        df_new[col] = df_new[col].astype(str).fillna('Missing')

df_new[categorical_variables] = df_new[categorical_variables].astype(str)


mask = df['construction year'].isnull()
values_present = df_new[~mask]
values_null = df_new[mask]

X_train = values_present.drop(columns=['construction year'])
X_test = values_null.drop(columns=['construction year'])
y_train = values_present['construction year']

cat_feature_indices = [X_train.columns.get_loc(c) for c in categorical_variables if c in X_train.columns]

model = CatBoostClassifier(cat_features=cat_feature_indices, verbose=0, iterations=10, early_stopping_rounds=5)
model.fit(X_train, y_train)

predictions = model.predict(X_test)
df_new.loc[mask, 'construction year'] = predictions

# %%
# TEST - one numerical variable - living area
mask = df['living area'].isnull()
values_present = df_new[~mask]
values_null = df_new[mask]

X_train = values_present.drop(columns=['living area'])
X_test = values_null.drop(columns=['living area'])
y_train = values_present['living area']

cat_feature_indices = [X_train.columns.get_loc(c) for c in categorical_variables if c in X_train.columns]

model = CatBoostRegressor(cat_features=cat_feature_indices, verbose=0, iterations=10, early_stopping_rounds=5)
model.fit(X_train, y_train)

predictions = model.predict(X_test)
df_new.loc[mask, 'living area'] = predictions

# %% [markdown]
# - In order for CatBoost to work, categorical variables must be casted as strings.

# %%
for col in categorical_variables:
    if isinstance(df_new[col].dtype, pd.CategoricalDtype):
        df_new[col] = df_new[col].cat.add_categories('Missing').fillna('Missing')
    else:
        df_new[col] = df_new[col].astype(str).fillna('Missing')

df_new[categorical_variables] = df_new[categorical_variables].astype(str)

# %%
# iteration for all categorical variables

verbose = True
for col in df_new: 
    if df_new[col].dtype == 'object':
        if verbose:
            print(f'Imputing {col}')
            mask = df[col].isnull()
            values_present = df_new[~mask]
            values_null = df_new[mask]

            X_train = values_present.drop(columns=col)
            X_test = values_null.drop(columns=col)
            y_train = values_present[col]

            cat_feature_indices = [X_train.columns.get_loc(c) for c in categorical_variables if c in X_train.columns]

            model = CatBoostClassifier(cat_features=cat_feature_indices, verbose=1, iterations=10, early_stopping_rounds=5)
            model.fit(X_train, y_train)

            predictions = model.predict(X_test)
            df_new.loc[mask, col] = predictions
            if verbose:
                print(f'Imputed {col}')
# Out:
# Imputing construction year
# Learning rate set to 0.5
# 2:	learn: 0.1448369	total: 5.55ms	remaining: 12.9ms
# 3:	learn: 0.1069626	total: 7.76ms	remaining: 11.6ms
# 4:	learn: 0.1026953	total: 9.22ms	remaining: 9.22ms
# 5:	learn: 0.0822173	total: 11.7ms	remaining: 7.78ms
# 6:	learn: 0.0656429	total: 13.9ms	remaining: 5.96ms
# 7:	learn: 0.0589535	total: 16.7ms	remaining: 4.17ms
# 8:	learn: 0.0544107	total: 18.9ms	remaining: 2.1ms
# 9:	learn: 0.0472210	total: 21.3ms	remaining: 0us
# Imputed double glazing

# %%
# iteration for all numerical values

numerical_variables = []
for col in df:
    if df[col].dtype == 'float':
        numerical_variables.append(col)

numerical_variables = numerical_variables[1:]


verbose = True
for col in numerical_variables:
    if verbose:
        print(f'Imputing {col}')
    mask = df[col].isnull()
    values_present = df_new[~mask]
    values_null = df_new[mask]

    X_train = values_present.drop(columns=[col])
    X_test = values_null.drop(columns=[col])
    y_train = values_present[col]

    cat_feature_indices = [X_train.columns.get_loc(c) for c in categorical_variables if c in X_train.columns]

    model = CatBoostRegressor(cat_features=cat_feature_indices, verbose=1, iterations=10, early_stopping_rounds=5)
    model.fit(X_train, y_train)

    predictions = model.predict(X_test)

    if (predictions < 0).any():
        med = df[col].median()
        predictions = med
    df_new.loc[mask, col] = predictions
    if verbose:
        print(f'Imputed {col}')
# Out:
# Imputing living area
# Learning rate set to 0.5
# 0:	learn: 115.7179011	total: 7.83ms	remaining: 70.4ms
# 1:	learn: 104.7094319	total: 10.6ms	remaining: 42.2ms
# 2:	learn: 96.3443374	total: 12.1ms	remaining: 28.2ms
# 3:	learn: 90.0803784	total: 18.2ms	remaining: 27.3ms
# 4:	learn: 82.4282499	total: 22.9ms	remaining: 22.9ms
# 5:	learn: 75.0455826	total: 24.7ms	remaining: 16.5ms
# 6:	learn: 72.2391614	total: 27.5ms	remaining: 11.8ms
# 7:	learn: 70.3422669	total: 31.2ms	remaining: 7.8ms
# 8:	learn: 69.6184800	total: 33.3ms	remaining: 3.7ms
# 9:	learn: 67.2968535	total: 36.4ms	remaining: 0us
# Imputed living area
# Imputing primary energy consumption
# Learning rate set to 0.5
# 0:	learn: 5364.9763712	total: 1.93ms	remaining: 17.4ms
# 1:	learn: 5157.1507551	total: 5.52ms	remaining: 22.1ms
# 2:	learn: 4512.9127583	total: 8.91ms	remaining: 20.8ms
# 3:	learn: 3958.1252920	total: 11.6ms	remaining: 17.5ms
# 4:	learn: 3469.7592853	total: 12.8ms	remaining: 12.8ms
# 5:	learn: 3047.3764172	total: 13.9ms	remaining: 9.3ms
# 6:	learn: 2677.6933834	total: 17ms	remaining: 7.29ms
# 7:	learn: 2652.6382121	total: 18.6ms	remaining: 4.66ms
# 8:	learn: 2339.2483166	total: 21.6ms	remaining: 2.4ms
# 9:	learn: 2131.5350549	total: 24.5ms	remaining: 0us
# Imputed primary energy consumption
# Imputing surface of the plot
# Learning rate set to 0.5
# 0:	learn: 2281.3391555	total: 1.56ms	remaining: 14ms
# 1:	learn: 2084.6509388	total: 8.85ms	remaining: 35.4ms
# 2:	learn: 1904.1551745	total: 10.1ms	remaining: 23.5ms
# 3:	learn: 1755.2459559	total: 11.5ms	remaining: 17.2ms
# 4:	learn: 1641.9245988	total: 13.2ms	remaining: 13.2ms
# 5:	learn: 1532.3232844	total: 14.6ms	remaining: 9.77ms
# 6:	learn: 1449.7629576	total: 17.4ms	remaining: 7.46ms
# 7:	learn: 1370.1996653	total: 18.4ms	remaining: 4.6ms
# 8:	learn: 1321.9498328	total: 18.9ms	remaining: 2.1ms
# 9:	learn: 1274.7282552	total: 20ms	remaining: 0us
# Imputed surface of the plot

# %% [markdown]
# # Model: Attempt 1

# %%
# prep
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# feature selection
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

# algorithms
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from xgboost import XGBRFRegressor
from sklearn.ensemble import RandomForestRegressor

# evaluation
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score

# %%
df_standardized = pd.DataFrame(StandardScaler().fit_transform(df_new), columns=df_new.columns)

# %%
X = df_standardized.drop(columns='price')
y = df_standardized['price']

# Standardize
X_normalized = StandardScaler().fit_transform(X)
# Select best features
kbest = SelectKBest(score_func=f_regression, k=12)
X_kbest = kbest.fit_transform(X_normalized, y)
X.columns[kbest.get_support()]
# Out:
# Index(['construction year', 'building condition', 'asbestos certificate',
#        'living area', 'bedrooms', 'bathrooms', 'toilets', 'energy class',
#        'subdivision permit', 'g-score', 'surface of the plot',
#        'designated land use'],
#       dtype='object')

# %%
kbest_df = pd.DataFrame(X_kbest, columns=X.columns[kbest.get_support()])
kbest_df.head(2)
# Out:
#    construction year  building condition  asbestos certificate  living area  \
# 0           0.753303           -1.522530             -1.039875    -0.124380
# 1           0.970668            0.196615             -1.039875    -0.545656
#
#    bedrooms  bathrooms  toilets  energy class  subdivision permit   g-score  \
# 0 -0.824478   -0.31829  0.23906     -0.447232           -0.649283 -0.428355
# 1 -0.824478   -0.31829  0.23906     -0.997574            1.540160 -0.428355
#
#    surface of the plot  designated land use
# 0            -0.167654            -0.406172
# 1            -0.092784            -0.406172

# %%
X_train, X_test, y_train, y_test = train_test_split(
    kbest_df, y,
    test_size=0.2,        
    random_state=2025,       
)

# %%
models = [LinearRegression(), Lasso(), Ridge(),
        XGBRFRegressor(enable_categorical=True, random_state=2025), RandomForestRegressor()
        ]

for i in range(len(models)):
    models[i].fit(X_train, y_train)
    print(f'{models[i]}: ')

    y_predictions = models[i].predict(X_test)

    rmse = root_mean_squared_error(y_test, y_predictions)
    mae = mean_absolute_error(y_test, y_predictions)
    r2 = r2_score(y_test, y_predictions)

    print(f'RMSE: {rmse:.2f}, MAE: {mae:.2f}, R²: {r2:.2f}')
# Out:
# LinearRegression():
# RMSE: 0.73, MAE: 0.45, R²: 0.50
# Lasso():
# RMSE: 1.03, MAE: 0.67, R²: -0.00
# Ridge():
# RMSE: 0.73, MAE: 0.45, R²: 0.50
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=True,
#                eval_metric=None, feature_types=None, feature_weights=None,
#                gamma=None, grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=2025, ...):
# RMSE: 0.63, MAE: 0.36, R²: 0.62
# RandomForestRegressor():
# RMSE: 0.66, MAE: 0.35, R²: 0.59
